# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
em=1
for det in range(4):
    for mod in ['fpma', 'fpmb']:
        infile = '{}_det{}_line{}.txt'.format(mod, det, em)
        f = open(infile)
        fits = []
        errorr = []
        hierr = []
        loerr = []
        for line in f:
        #    print(line)
            fields = line.split()
            fits.append(float(fields[0]))
            hierr.append(float(fields[2]) - float(fields[0]))
            loerr.append(float(fields[0]) - float(fields[1]))    
        f.close()

        plt.xlabel('Years since Launch')
        plt.ylabel('Line Centroid (keV)')
        #plt.plot(range(len(fits)), fits, 'o')
        plt.errorbar(range(len(fits)), fits, loerr, fmt='.', label='{}'.format(det))
        break
    plt.legend()
plt.title('FPMA')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-382feaa187a2> in <module>()
#      21         plt.errorbar(range(len(fits)), fits, loerr, fmt='.', label='{}'.format(det))
#      22         break
# ---> 23     plt.legend()
#      24 plt.title('FPMA')
#      25 plt.show()
#
# /Users/bwgref/science/local/anaconda/lib/python3.5/site-packages/matplotlib/pyplot.py in legend(*args, **kwargs)
#    3796 @docstring.copy_dedent(Axes.legend)
#    3797 def legend(*args, **kwargs):
# -> 3798     ret = gca().legend(*args, **kwargs)
#    3799     return ret
#    3800
#
# /Users/bwgref/science/local/anaconda/lib/python3.5/site-packages/matplotlib/axes/_axes.py in legend(self, *args, **kwargs)
#     562             raise TypeError('Invalid arguments to legend.')
#     563
# --> 564         self.legend_ = mlegend.Legend(self, handles, labels, **kwargs)
# ...

# %%
em=1
for det in range(4):
    for mod in ['fpmb', 'fpmb']:
        infile = '{}_det{}_line{}.txt'.format(mod, det, em)
        f = open(infile)
        fits = []
        errorr = []
        hierr = []
        loerr = []
        for line in f:
        #    print(line)
            fields = line.split()
            fits.append(float(fields[0]))
            hierr.append(float(fields[2]) - float(fields[0]))
            loerr.append(float(fields[0]) - float(fields[1]))    
        f.close()

        plt.xlabel('Years since Launch')
        plt.ylabel('Line Centroid (keV)')
        #plt.plot(range(len(fits)), fits, 'o')
        plt.errorbar(range(len(fits)), fits, loerr, fmt='.', label='{}'.format(det))
        break
    plt.legend()
plt.title('FPMB')
plt.show()

# %%
em=3
for det in range(4):
    for mod in ['fpma', 'fpmb']:
        infile = '{}_det{}_line{}.txt'.format(mod, det, em)
        f = open(infile)
        fits = []
        errorr = []
        hierr = []
        loerr = []
        for line in f:
        #    print(line)
            fields = line.split()
            fits.append(float(fields[0]))
            hierr.append(float(fields[2]) - float(fields[0]))
            loerr.append(float(fields[0]) - float(fields[1]))    
        f.close()

        plt.xlabel('Years since Launch')
        plt.ylabel('Line Centroid (keV)')
        #plt.plot(range(len(fits)), fits, 'o')
        plt.errorbar(range(len(fits)), fits, loerr, fmt='.', label='{}'.format(det))
        break
    plt.legend()
plt.title('FPMA')
plt.show()

# %%
em=3
for det in range(4):
    for mod in ['fpmb', 'fpmb']:
        infile = '{}_det{}_line{}.txt'.format(mod, det, em)
        f = open(infile)
        fits = []
        errorr = []
        hierr = []
        loerr = []
        for line in f:
        #    print(line)
            fields = line.split()
            fits.append(float(fields[0]))
            hierr.append(float(fields[2]) - float(fields[0]))
            loerr.append(float(fields[0]) - float(fields[1]))    
        f.close()

        plt.xlabel('Years since Launch')
        plt.ylabel('Line Centroid (keV)')
        #plt.plot(range(len(fits)), fits, 'o')
        plt.errorbar(range(len(fits)), fits, loerr, fmt='.', label='{}'.format(det))
        break
    plt.legend()
plt.title('FPMB')
plt.show()
