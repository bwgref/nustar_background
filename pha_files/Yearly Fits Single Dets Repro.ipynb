# %%
from matplotlib import pyplot as plt
import matplotlib

# %matplotlib inline
import astropy.units as u

gain_met = 159663600. # from CALDB file
launch_met=77241600. # 2012-06-13T00:00:00

last_cal_year = ( (gain_met - launch_met)*u.s).to(u.yr)
print(last_cal_year)

font = {'family' : 'normal',
        'size'   : 16}
matplotlib.rc('font', **font)
# Out:
# 2.611795573807894 yr

# %%
em=3
plt.figure(figsize=(20,10))


for mod in ['fpma', 'fpmb']:
    infile = '{}_det3_line{}_repro.txt'.format(mod, em)
    f = open(infile)
    print(infile)
    fits = []
    errorr = []
    hierr = []
    loerr = []
    for line in f:
        print(line)
        fields = line.split()
        fits.append(float(fields[0]))
        hierr.append((float(fields[2]) - float(fields[0])))
        loerr.append((float(fields[0]) - float(fields[1])))
    f.close()

    plt.xlabel('Years since Launch')
    plt.ylabel('Line Centroid (keV)')
    #plt.plot(range(len(fits)), fits, 'o')
    plt.errorbar(range(len(fits)), fits, loerr, fmt='.', label=mod)

    
plt.axvline(x=last_cal_year.value, color = 'r', linestyle='--')

plt.legend()
plt.title('Det 0')

plt.show()
# Out:
# fpma_det3_line3_repro.txt
# 105.382 105.3095136 105.4218866  FFFFFFFFF
#
# 105.142 105.0870613 105.1951848  FFFFFFFFF
#
# 105.084 105.0122054 105.140599  FFFFFFFFF
#
# 104.97 104.9053969 105.0471436  FFFFFFFFF
#
# 104.937 104.8384881 104.9853388  FFFFFFFFF
#
# 104.91 104.7976079 104.9462912  FFFFFFFFF
#
# fpmb_det3_line3_repro.txt
# 105.398 105.3491984 105.4570976  FFFFFFFFF
#
# 105.189 105.1215484 105.2321055  FFFFFFFFF
#
# 105.119 105.0486683 105.1766884  FFFFFFFFF
#
# 105.035 104.9391913 105.0874663  FFFFFFFFF
#
# 104.955 104.8798886 105.0182535  FFFFFFFFF
#
# 104.925 104.8414949 104.9739488  FFFFFFFFF
# /Users/bwgref/science/local/anaconda/lib/python3.5/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
em=3
plt.figure(figsize=(20,10))


for det in range(4):
    for mod in ['fpma', 'fpmb']:
        infile = '{}_det{}_line{}_repro.txt'.format(mod, det, em)
        f = open(infile)
        fits = []
        errorr = []
        hierr = []
        loerr = []
        for line in f:
        #    print(line)
            fields = line.split()
            fits.append(float(fields[0]))
            hierr.append(float(fields[2]) - float(fields[0]))
            loerr.append(float(fields[0]) - float(fields[1]))    
        f.close()

        plt.xlabel('Years since Launch')
        plt.ylabel('Line Centroid (keV)')
        #plt.plot(range(len(fits)), fits, 'o')
        plt.errorbar(range(len(fits)), fits, loerr, fmt='.', label='{}'.format(det))
        break
    plt.legend()

plt.axvline(x=last_cal_year.value, color = 'r', linestyle='--')


plt.title('FPMA')
plt.show()
# Out:
# /Users/bwgref/science/local/anaconda/lib/python3.5/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
em=1
plt.figure(figsize=(20,10))


for det in range(4):
    for mod in ['fpmb', 'fpmb']:
        infile = '{}_det{}_line{}_repro.txt'.format(mod, det, em)
        f = open(infile)
        fits = []
        errorr = []
        hierr = []
        loerr = []
        for line in f:
            print(line)
            fields = line.split()
            fits.append(float(fields[0]))
            hierr.append(float(fields[2]) - float(fields[0]))
            loerr.append(float(fields[0]) - float(fields[1]))    
        f.close()
        print()
        plt.xlabel('Years since Launch')
        plt.ylabel('Line Centroid (keV)')
        #plt.plot(range(len(fits)), fits, 'o')
        plt.errorbar(range(len(fits)), fits, loerr, fmt='.', label='{}'.format(det))
        break
    plt.legend()
plt.axvline(x=last_cal_year.value, color = 'r', linestyle='--')


plt.axvline(x=last_cal_year.value, color = 'r', linestyle='--')


plt.title('FPMB')
plt.show()
# Out:
# 144.606 144.5624271 144.6496674  FFFFFFFFF
#
# 144.411 144.3853386 144.4618071  FFFFFFFFF
#
# 144.238 144.2275705 144.3173544  FFFFFFFFF
#
# 144.126 144.0812822 144.1720583  FFFFFFFFF
#
# 144.052 144.0322986 144.1318014  FFFFFFFFF
#
# 143.979 143.9368018 144.0303011  FFFFFFFFF
#
#
# 144.598 144.5657137 144.660556  FFFFFFFFF
#
# 144.417 144.3896667 144.4617122  FFFFFFFFF
#
# 144.234 144.2336852 144.3229923  FFFFFFFFF
#
# 144.124 144.0879812 144.1797147  FFFFFFFFF
#
# 144.04 144.0388077 144.1347568  FFFFFFFFF
#
# 143.99 143.9452396 144.0390677  FFFFFFFFF
#
#
# 144.546 144.5128702 144.6047349  FFFFFFFFF
#
# 144.37 144.33838 144.4098113  FFFFFFFFF
#
# 144.181 144.1803882 144.2705881  FFFFFFFFF
#
# 144.083 144.0399012 144.1287089  FFFFFFFFF
#
# 144.018 143.9814257 144.086502  FFFFFFFFF
#
# 143.928 143.8926583 143.9856202  FFFFFFFFF
#
#
# 144.585 144.5489631 144.6432244  FFFFFFFFF
#
# 144.4 144.3723237 144.4460746  FFFFFFFFF
#
# 144.215 144.2156635 144.305971  FFFFFFFFF
#
# 144.106 144.0717712 144.1647485  FFFFFFFFF
#
# 144.041 144.0223082 144.1200498  FFFFFFFFF
#
# 143.977 143.9315659 144.0232476  FFFFFFFFF
# /Users/bwgref/science/local/anaconda/lib/python3.5/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
em=3
plt.figure(figsize=(20,10))


for det in range(4):
    for mod in ['fpma', 'fpmb']:
        infile = '{}_det{}_line{}_repro.txt'.format(mod, det, em)
        f = open(infile)
        fits = []
        errorr = []
        hierr = []
        loerr = []
        for line in f:
        #    print(line)
            fields = line.split()
            fits.append(float(fields[0]))
            hierr.append(float(fields[2]) - float(fields[0]))
            loerr.append(float(fields[0]) - float(fields[1]))    
        f.close()

        plt.xlabel('Years since Launch')
        plt.ylabel('Line Centroid (keV)')
        #plt.plot(range(len(fits)), fits, 'o')
        plt.errorbar(range(len(fits)), fits, loerr, fmt='.', label='{}'.format(det))
        break
    plt.legend()

plt.axvline(x=last_cal_year.value, color = 'r', linestyle='--')


plt.title('FPMA')
plt.show()
# Out:
# /Users/bwgref/science/local/anaconda/lib/python3.5/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
em=1
plt.figure(figsize=(20,10))


for det in range(4):
    for mod in ['fpmb', 'fpmb']:
        infile = '{}_det{}_line{}_repro.txt'.format(mod, det, em)
        f = open(infile)
        fits = []
        errorr = []
        hierr = []
        loerr = []
        for line in f:
        #    print(line)
            fields = line.split()
            fits.append(float(fields[0]))
            hierr.append(float(fields[2]) - float(fields[0]))
            loerr.append(float(fields[0]) - float(fields[1]))    
        f.close()

        plt.xlabel('Years since Launch')
        plt.ylabel('Line Centroid (keV)')
        #plt.plot(range(len(fits)), fits, 'o')
        plt.errorbar(range(len(fits)), fits, loerr, fmt='.', label='{}'.format(det))
        break
plt.legend()
plt.axvline(x=last_cal_year.value, color = 'r', linestyle='--')


plt.title('FPMB')
plt.show()
# Out:
# /Users/bwgref/science/local/anaconda/lib/python3.5/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
print('105.4 keV @ 0.2% per year: {}'.format(0.002*105.4))
print('144.6 keV @ 0.2% per year: {}'.format(0.002*144.6))
# Out:
# 105.4 keV @ 0.2% per year: 0.21080000000000002
# 144.6 keV @ 0.2% per year: 0.2892

# %%
f = open('IncidentEu155SpecWholeCZTWithError.dat')
energy = []
flux = []
for line in f:
    fields = line.split()
    if '#' in line:
        continue
    energy.append(float(fields[0]))
    flux.append(float(fields[2]))

# %%
plt.plot(energy, flux)
plt.xlim([140, 150])
# Out:
# (140, 150)
# /Users/bwgref/science/local/anaconda/lib/python3.5/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
